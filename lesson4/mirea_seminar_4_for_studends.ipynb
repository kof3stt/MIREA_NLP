# %% [markdown]
# **Семинар 3**
# План занятия:
# - разбор класса Value (сторим собственный autograd)
# - обучение параметров полинома
# - построение MLP модели на основе класса Value
# - теоретический блок по визуализации обучения (wandb)
# - обучение собственной MLP модели

# %% [markdown]
# #Разбор класса Value

# %% [markdown]
# # Oбучение полинома

# %%
import numpy as np
import math
import random

xx = np.linspace(-math.pi, math.pi, 2000)
yy = np.sin(xx).tolist()

# %% [markdown]
# ### Класс Value

# %%
class Value:
    """ stores a single scalar value and its gradient """

    def __init__(self, data, _children=(), _op=''):
        self.data = data
        self.grad = 0
        # internal variables used for autograd graph construction
        self._backward = lambda: None # function
        self._prev = set(_children) # set of Value objects
        self._op = _op # the op that produced this node, string ('+', '-', ....)

    def __add__(self, other):
        other = other if isinstance(other, Value) else Value(other)
        out = Value(data=self.data + other.data, _children=(self, other), _op='+')

        def _backward():
            self.grad += out.grad
            other.grad += out.grad
        out._backward = _backward

        return out

    def __mul__(self, other):
        other = other if isinstance(other, Value) else Value(other)
        out = Value(data=self.data * other.data, _children=(self, other), _op='*')

        def _backward():
            self.grad += other.data * out.grad
            other.grad += self.data * out.grad
        out._backward = _backward

        return out

    def __pow__(self, other):
        assert isinstance(other, (int, float)), "only supporting int/float powers for now"
        out = Value(data=self.data ** other, _children=(self,), _op=f'**{other}')

        def _backward():
            self.grad += (other * self.data**(other - 1)) * out.grad
        out._backward = _backward

        return out

    def relu(self):
        out = Value(data=self.data if self.data > 0 else 0, _children=(self,), _op='ReLU')

        def _backward():
            self.grad += (out.data > 0) * out.grad
        out._backward = _backward

        return out

    def backward(self):
        # topological order all of the children in the graph
        topo = []
        visited = set()
        def build_topo(v):
            if v not in visited:
                visited.add(v)
                for child in v._prev:
                    build_topo(child)
                topo.append(v)
        build_topo(self)

        # go one variable at a time and apply the chain rule to get its gradient
        self.grad = 1
        for v in reversed(topo):
            v._backward()

    def __neg__(self): # -self
        return self * -1

    def __radd__(self, other): # other + self
        return self + other

    def __sub__(self, other): # self - other
        return self + (-other)

    def __rsub__(self, other): # other - self
        return other + (-self)

    def __rmul__(self, other): # other * self
        return self * other

    def __truediv__(self, other): # self / other
        return self * other**-1

    def __rtruediv__(self, other): # other / self
        return other * self**-1

    def __repr__(self):
        return f"Value(data={self.data}, grad={self.grad})"

# %%
a = Value(random.uniform(-1,1))
b = Value(random.uniform(-1,1))
c = Value(random.uniform(-1,1))
d = Value(random.uniform(-1,1))
parameters = [a, b, c, d]

# %%
pseudo_sin = lambda x: 1 * a + x * b + x ** 2 * c + x ** 3 * d

# %%
import sys
print(sys.getrecursionlimit())
# Out:
# 5000

# %%
sys.setrecursionlimit(5000)

# %%
#%%wandb
lr = 0.1

for step in range(2000):
  polynom = pseudo_sin(xx[step])

  loss = (yy[step] - polynom) ** 2

  #wandb.log({'loss': loss.data})

  if step % 10 == 0:
      print(f"{step} step - loss {loss}")

  #set grad to zero
  for parameter in parameters:
    parameter.grad = 0

  #call backward
  loss.backward()

  #update weights
  for parameter in parameters:
    parameter -= lr * parameter.grad

print(f'Result: y = {a.data} + {b.data} x + {c.data} x^2 + {d.data} x^3')
# Out:
# 0 step - loss Value(data=905.3549778095306, grad=0)
# 10 step - loss Value(data=858.3353128586133, grad=0)
# 20 step - loss Value(data=813.4219315991133, grad=0)
# 30 step - loss Value(data=770.5360160984877, grad=0)
# 40 step - loss Value(data=729.6010767136727, grad=0)
# 50 step - loss Value(data=690.542904839407, grad=0)
# 60 step - loss Value(data=653.2895259565362, grad=0)
# 70 step - loss Value(data=617.7711529971427, grad=0)
# 80 step - loss Value(data=583.9201400430383, grad=0)
# 90 step - loss Value(data=551.6709363738381, grad=0)
# 100 step - loss Value(data=520.9600408804922, grad=0)
# 110 step - loss Value(data=491.72595685977876, grad=0)
# 120 step - loss Value(data=463.9091472048693, grad=0)
# 130 step - loss Value(data=437.45199000665986, grad=0)
# 140 step - loss Value(data=412.298734580133, grad=0)
# 150 step - loss Value(data=388.39545792955505, grad=0)
# 160 step - loss Value(data=365.69002166584517, grad=0)
# 170 step - loss Value(data=344.13202938895915, grad=0)
# 180 step - loss Value(data=323.67278454763476, grad=0)
# 190 step - loss Value(data=304.26524878832123, grad=0)
# 200 step - loss Value(data=285.86400080458964, grad=0)
# 210 step - loss Value(data=268.4251956977716, grad=0)
# 220 step - loss Value(data=251.90652485903775, grad=0)
# 230 step - loss Value(data=236.267176382549, grad=0)
# 240 step - loss Value(data=221.46779601875767, grad=0)
# 250 step - loss Value(data=207.4704486763619, grad=0)
# 260 step - loss Value(data=194.2385804808277, grad=0)
# 270 step - loss Value(data=181.73698139682637, grad=0)
# 280 step - loss Value(data=169.9317484213377, grad=0)
# 290 step - loss Value(data=158.7902493535883, grad=0)
# 300 step - loss Value(data=148.28108714741086, grad=0)
# 310 step - loss Value(data=138.37406485102102, grad=0)
# 320 step - loss Value(data=129.04015113862954, grad=0)
# 330 step - loss Value(data=120.25144643772614, grad=0)
# 340 step - loss Value(data=111.98114965529803, grad=0)
# 350 step - loss Value(data=104.20352550567654, grad=0)
# 360 step - loss Value(data=96.89387244214022, grad=0)
# 370 step - loss Value(data=90.02849119385164, grad=0)
# 380 step - loss Value(data=83.58465390915237, grad=0)
# 390 step - loss Value(data=77.54057390570624, grad=0)
# 400 step - loss Value(data=71.87537602745093, grad=0)
# 410 step - loss Value(data=66.56906760780005, grad=0)
# 420 step - loss Value(data=61.602510038033465, grad=0)
# 430 step - loss Value(data=56.95739093931681, grad=0)
# 440 step - loss Value(data=52.616196936313706, grad=0)
# 450 step - loss Value(data=48.562187029883134, grad=0)
# 460 step - loss Value(data=44.77936656590362, grad=0)
# 470 step - loss Value(data=41.252461796825735, grad=0)
# 480 step - loss Value(data=37.96689503213108, grad=0)
# 490 step - loss Value(data=34.908760373468674, grad=0)
# 500 step - loss Value(data=32.064800029846054, grad=0)
# 510 step - loss Value(data=29.42238120787894, grad=0)
# 520 step - loss Value(data=26.96947357174324, grad=0)
# 530 step - loss Value(data=24.69462726713169, grad=0)
# 540 step - loss Value(data=22.586951503194026, grad=0)
# 550 step - loss Value(data=20.636093686131687, grad=0)
# 560 step - loss Value(data=18.832219097830443, grad=0)
# 570 step - loss Value(data=17.165991112642192, grad=0)
# 580 step - loss Value(data=15.628551945175497, grad=0)
# 590 step - loss Value(data=14.211503921718952, grad=0)
# 600 step - loss Value(data=12.906891267705214, grad=0)
# 610 step - loss Value(data=11.707182403425671, grad=0)
# 620 step - loss Value(data=10.605252740025307, grad=0)
# 630 step - loss Value(data=9.594367967646008, grad=0)
# 640 step - loss Value(data=8.66816782744267, grad=0)
# 650 step - loss Value(data=7.820650359071368, grad=0)
# 660 step - loss Value(data=7.0461566151409185, grad=0)
# 670 step - loss Value(data=6.339355834029902, grad=0)
# 680 step - loss Value(data=5.69523106239893, grad=0)
# 690 step - loss Value(data=5.109065218673469, grad=0)
# 700 step - loss Value(data=4.576427588735525, grad=0)
# 710 step - loss Value(data=4.093160745042082, grad=0)
# 720 step - loss Value(data=3.6553678803850027, grad=0)
# 730 step - loss Value(data=3.2594005475203978, grad=0)
# 740 step - loss Value(data=2.901846795924947, grad=0)
# 750 step - loss Value(data=2.5795196969823535, grad=0)
# 760 step - loss Value(data=2.289446248964259, grad=0)
# 770 step - loss Value(data=2.0288566532468795, grad=0)
# 780 step - loss Value(data=1.7951739532962006, grad=0)
# 790 step - loss Value(data=1.5860040280611951, grad=0)
# 800 step - loss Value(data=1.3991259315354454, grad=0)
# 810 step - loss Value(data=1.232482570382444, grad=0)
# 820 step - loss Value(data=1.0841717116685283, grad=0)
# 830 step - loss Value(data=0.9524373129092024, grad=0)
# 840 step - loss Value(data=0.8356611668095373, grad=0)
# 850 step - loss Value(data=0.7323548532665224, grad=0)
# 860 step - loss Value(data=0.6411519914007716, grad=0)
# 870 step - loss Value(data=0.5608007845960815, grad=0)
# 880 step - loss Value(data=0.4901568517478124, grad=0)
# 890 step - loss Value(data=0.42817633815438433, grad=0)
# 900 step - loss Value(data=0.3739092997299755, grad=0)
# 910 step - loss Value(data=0.32649335447036576, grad=0)
# 920 step - loss Value(data=0.285147595367284, grad=0)
# 930 step - loss Value(data=0.249166759239254, grad=0)
# 940 step - loss Value(data=0.21791564622825543, grad=0)
# 950 step - loss Value(data=0.1908237850011546, grad=0)
# 960 step - loss Value(data=0.16738033899230578, grad=0)
# 970 step - loss Value(data=0.14712924932854934, grad=0)
# 980 step - loss Value(data=0.1296646103895914, grad=0)
# 990 step - loss Value(data=0.11462627427492697, grad=0)
# 1000 step - loss Value(data=0.1016956807726494, grad=0)
# 1010 step - loss Value(data=0.09059190975515943, grad=0)
# 1020 step - loss Value(data=0.0810679532614836, grad=0)
# 1030 step - loss Value(data=0.0729072048651401, grad=0)
# 1040 step - loss Value(data=0.06592016426976179, grad=0)
# 1050 step - loss Value(data=0.05994135542150529, grad=0)
# 1060 step - loss Value(data=0.054826456777129315, grad=0)
# 1070 step - loss Value(data=0.05044964271901577, grad=0)
# 1080 step - loss Value(data=0.04670113546280919, grad=0)
# 1090 step - loss Value(data=0.04348496715924905, grad=0)
# 1100 step - loss Value(data=0.04071695224862971, grad=0)
# 1110 step - loss Value(data=0.038322870483616656, grad=0)
# 1120 step - loss Value(data=0.03623686139332994, grad=0)
# 1130 step - loss Value(data=0.03440003131813245, grad=0)
# 1140 step - loss Value(data=0.032759274499875625, grad=0)
# 1150 step - loss Value(data=0.031266310065903025, grad=0)
# 1160 step - loss Value(data=0.029876937096325325, grad=0)
# 1170 step - loss Value(data=0.02855051031238863, grad=0)
# 1180 step - loss Value(data=0.02724963926858544, grad=0)
# 1190 step - loss Value(data=0.025940114271926953, grad=0)
# 1200 step - loss Value(data=0.024591062587911727, grad=0)
# 1210 step - loss Value(data=0.023175338823613025, grad=0)
# 1220 step - loss Value(data=0.021670153703356614, grad=0)
# 1230 step - loss Value(data=0.02005794577109135, grad=0)
# 1240 step - loss Value(data=0.018327500865152415, grad=0)
# 1250 step - loss Value(data=0.016475324515096035, grad=0)
# 1260 step - loss Value(data=0.014507272706029816, grad=0)
# 1270 step - loss Value(data=0.012440446742782336, grad=0)
# 1280 step - loss Value(data=0.010305358223744922, grad=0)
# 1290 step - loss Value(data=0.00814837040167837, grad=0)
# 1300 step - loss Value(data=0.00603442246561197, grad=0)
# 1310 step - loss Value(data=0.004050043523581142, grad=0)
# 1320 step - loss Value(data=0.002306663299765599, grad=0)
# 1330 step - loss Value(data=0.000944226781018839, grad=0)
# 1340 step - loss Value(data=0.0001351202562553925, grad=0)
# 1350 step - loss Value(data=8.841638711483326e-05, grad=0)
# 1360 step - loss Value(data=0.0010544461292014678, grad=0)
# 1370 step - loss Value(data=0.0033297054894642015, grad=0)
# 1380 step - loss Value(data=0.007262105256402373, grad=0)
# 1390 step - loss Value(data=0.013256571975250856, grad=0)
# 1400 step - loss Value(data=0.021781008559609523, grad=0)
# 1410 step - loss Value(data=0.033372623033671014, grad=0)
# 1420 step - loss Value(data=0.04864463398478816, grad=0)
# 1430 step - loss Value(data=0.0682933613741928, grad=0)
# 1440 step - loss Value(data=0.09310571140381121, grad=0)
# 1450 step - loss Value(data=0.12396706416890227, grad=0)
# 1460 step - loss Value(data=0.16186957283935707, grad=0)
# 1470 step - loss Value(data=0.20792088310657203, grad=0)
# 1480 step - loss Value(data=0.26335328160753263, grad=0)
# 1490 step - loss Value(data=0.32953328199286347, grad=0)
# 1500 step - loss Value(data=0.4079716572409156, grad=0)
# 1510 step - loss Value(data=0.5003339267351049, grad=0)
# 1520 step - loss Value(data=0.6084513065167376, grad=0)
# 1530 step - loss Value(data=0.7343321310001739, grad=0)
# 1540 step - loss Value(data=0.8801737542912911, grad=0)
# 1550 step - loss Value(data=1.0483749390838768, grad=0)
# 1560 step - loss Value(data=1.241548740921641, grad=0)
# 1570 step - loss Value(data=1.4625358954061307, grad=0)
# 1580 step - loss Value(data=1.7144187157030115, grad=0)
# 1590 step - loss Value(data=2.000535507450957, grad=0)
# 1600 step - loss Value(data=2.3244955079091243, grad=0)
# 1610 step - loss Value(data=2.690194355890884, grad=0)
# 1620 step - loss Value(data=3.1018300987235103, grad=0)
# 1630 step - loss Value(data=3.5639197421461475, grad=0)
# 1640 step - loss Value(data=4.081316348712184, grad=0)
# 1650 step - loss Value(data=4.659226689896745, grad=0)
# 1660 step - loss Value(data=5.303229456727181, grad=0)
# 1670 step - loss Value(data=6.019294033353395, grad=0)
# 1680 step - loss Value(data=6.813799837556677, grad=0)
# 1690 step - loss Value(data=7.693556231761386, grad=0)
# 1700 step - loss Value(data=8.665823007663084, grad=0)
# 1710 step - loss Value(data=9.738331447121329, grad=0)
# 1720 step - loss Value(data=10.919305961484852, grad=0)
# 1730 step - loss Value(data=12.217486311023455, grad=0)
# 1740 step - loss Value(data=13.64215040563393, grad=0)
# 1750 step - loss Value(data=15.203137687468963, grad=0)
# 1760 step - loss Value(data=16.910873095608387, grad=0)
# 1770 step - loss Value(data=18.776391612352043, grad=0)
# 1780 step - loss Value(data=20.811363390166054, grad=0)
# 1790 step - loss Value(data=23.028119457755356, grad=0)
# 1800 step - loss Value(data=25.43967800317428, grad=0)
# 1810 step - loss Value(data=28.059771231315846, grad=0)
# 1820 step - loss Value(data=30.90287279254673, grad=0)
# 1830 step - loss Value(data=33.98422577867811, grad=0)
# 1840 step - loss Value(data=37.31987128188209, grad=0)
# 1850 step - loss Value(data=40.926677511583144, grad=0)
# 1860 step - loss Value(data=44.82236946377372, grad=0)
# 1870 step - loss Value(data=49.025559136624366, grad=0)
# 1880 step - loss Value(data=53.55577628568293, grad=0)
# 1890 step - loss Value(data=58.433499711385835, grad=0)
# 1900 step - loss Value(data=63.68018907103894, grad=0)
# 1910 step - loss Value(data=69.31831720686463, grad=0)
# 1920 step - loss Value(data=75.37140298116584, grad=0)
# 1930 step - loss Value(data=81.86404460910904, grad=0)
# 1940 step - loss Value(data=88.82195347910732, grad=0)
# 1950 step - loss Value(data=96.27198845025877, grad=0)
# 1960 step - loss Value(data=104.24219061579949, grad=0)
# 1970 step - loss Value(data=112.76181852103473, grad=0)
# 1980 step - loss Value(data=121.8613838237455, grad=0)
# 1990 step - loss Value(data=131.572687384611, grad=0)
# Result: y = 0.319838446257549 + 0.3999412532172968 x + 0.8906566701853518 x^2 + -0.7171226187341488 x^3

# %%
import matplotlib.pyplot as plt
plt.plot(xx, [y.data for y in list(map(pseudo_sin, xx))])

# %% [markdown]
# #Построение MLP модели на основе класса Value

# %%
import random

class Module:

    def zero_grad(self):
        for p in parameters:
            p.grad = 0

    def parameters(self):
        return []

class Neuron(Module):

    def __init__(self, nin, nonlin=True):
        self.w = [Value(random.uniform(-1,1)) for _ in range(nin)]
        self.b = Value(random.uniform(-1,1))
        self.nonlin = nonlin

    def __call__(self, x):
        act = sum([x[i] * self.w[i] for i in range(len(self.w))]) + self.b
        return act.Relu() if self.nonlin else act

    def parameters(self):
        return self.w + [self.b]

    def __repr__(self):
        return f"{'ReLU' if self.nonlin else 'Linear'}Neuron({len(self.w)})"

class Layer(Module):

    def __init__(self, nin, nout, **kwargs):
        self.neurons = [Neuron(nin) for _ in range(nout)]

    def __call__(self, x):
        out = [neuron(x) for neuron in self.neurons]
        return out[0] if len(out) == 1 else out

    def parameters(self):
        out = []
        for neuron in self.neurons:
            out.extend(neuron.parameters)
        return out

    def __repr__(self):
        return f"Layer of [{', '.join(str(n) for n in self.neurons)}]"

class MLP(Module):

    def __init__(self, nin, nouts):
        sz = [nin] + nouts
        self.layers = [Layer(sz[i], sz[i+1], nonlin=(i!=len(nouts)-1)) for i in range(len(nouts))]

    def __call__(self, x):
        for layer in self.layers:
            x = layer(x)
        return x

    def parameters(self):
        params = []
        for layer in self.layers:
            params.extend(layer.parameters())
        return params

    def __repr__(self):
        repr = '\n'.join(str(layer) for layer in self.layers)
        return f"MLP of [{repr}]"

# %% [markdown]
# # Визуализация обучения

# %% [markdown]
# https://docs.wandb.ai/guides/integrations/pytorch

# %% [markdown]
# https://docs.wandb.ai/ref/python/watch

# %% [markdown]
# https://docs.wandb.ai/guides/track/jupyter

# %%
# !pip install wandb
# Out:
# Requirement already satisfied: wandb in c:\users\kof3st\appdata\local\programs\python\python313\lib\site-packages (0.22.2)
# Requirement already satisfied: click>=8.0.1 in c:\users\kof3st\appdata\local\programs\python\python313\lib\site-packages (from wandb) (8.3.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in c:\users\kof3st\appdata\local\programs\python\python313\lib\site-packages (from wandb) (3.1.45)
# Requirement already satisfied: packaging in c:\users\kof3st\appdata\local\programs\python\python313\lib\site-packages (from wandb) (25.0)
# Requirement already satisfied: platformdirs in c:\users\kof3st\appdata\local\programs\python\python313\lib\site-packages (from wandb) (4.5.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in c:\users\kof3st\appdata\local\programs\python\python313\lib\site-packages (from wandb) (6.33.0)
# Requirement already satisfied: pydantic<3 in c:\users\kof3st\appdata\local\programs\python\python313\lib\site-packages (from wandb) (2.12.3)
# Requirement already satisfied: pyyaml in c:\users\kof3st\appdata\local\programs\python\python313\lib\site-packages (from wandb) (6.0.3)
# Requirement already satisfied: requests<3,>=2.0.0 in c:\users\kof3st\appdata\local\programs\python\python313\lib\site-packages (from wandb) (2.32.5)
# Requirement already satisfied: sentry-sdk>=2.0.0 in c:\users\kof3st\appdata\local\programs\python\python313\lib\site-packages (from wandb) (2.42.1)
# Requirement already satisfied: typing-extensions<5,>=4.8 in c:\users\kof3st\appdata\local\programs\python\python313\lib\site-packages (from wandb) (4.15.0)
# Requirement already satisfied: colorama in c:\users\kof3st\appdata\local\programs\python\python313\lib\site-packages (from click>=8.0.1->wandb) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\kof3st\appdata\local\programs\python\python313\lib\site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\kof3st\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\users\kof3st\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3->wandb) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\kof3st\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3->wandb) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kof3st\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.0.0->wandb) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kof3st\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.0.0->wandb) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kof3st\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.0.0->wandb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kof3st\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.0.0->wandb) (2025.10.5)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\kof3st\appdata\local\programs\python\python313\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: C:\Users\kof3st\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %%
# !wandb login
# Out:
# C:\Users\kof3st\AppData\Local\Programs\Python\Python313\Lib\site-packages\pydantic\_internal\_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# C:\Users\kof3st\AppData\Local\Programs\Python\Python313\Lib\site-packages\pydantic\_internal\_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# wandb: ERROR Find detailed error logs at: C:\Users\kof3st\AppData\Local\Temp\debug-cli.kof3st.log
# Error: api_key not configured (no-tty). call wandb login [your_api_key]

# %%
import wandb
run = wandb.init(project="polynom_learning_")
# Out:
# c:\python_projects\MIREA_NLP\.venv\Lib\site-packages\pydantic\_internal\_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# c:\python_projects\MIREA_NLP\.venv\Lib\site-packages\pydantic\_internal\_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
# ---------------------------------------------------------------------------
# Abort                                     Traceback (most recent call last)
# Cell In[50], line 2
#       1 import wandb
# ----> 2 run = wandb.init(project="polynom_learning_")
#
# File c:\python_projects\MIREA_NLP\.venv\Lib\site-packages\wandb\sdk\wandb_init.py:1601, in init(entity, project, dir, id, name, notes, tags, config, config_exclude_keys, config_include_keys, allow_val_change, group, job_type, mode, force, anonymous, reinit, resume, resume_from, fork_from, save_code, tensorboard, sync_tensorboard, monitor_gym, settings)
#    1597     wl._get_logger().exception("error in wandb.init()", exc_info=e)
#    1599 # Need to build delay into this sentry capture because our exit hooks
#    1600 # mess with sentry's ability to send out errors before the program ends.
# -> 1601 wandb._sentry.reraise(e)
#
# File c:\python_projects\MIREA_NLP\.venv\Lib\site-packages\wandb\analytics\sentry.py:162, in Sentry.reraise(self, exc)
#     159 self.exception(exc)
#     160 # this will messily add this "reraise" function to the stack trace,
#     161 # but hopefully it's not too bad
# --> 162 raise exc.with_traceback(sys.exc_info()[2])
#
# File c:\python_projects\MIREA_NLP\.venv\Lib\site-packages\wandb\sdk\wandb_init.py:1523, in init(entity, project, dir, id, name, notes, tags, config, config_exclude_keys, config_include_keys, allow_val_change, group, job_type, mode, force, anonymous, reinit, resume, resume_from, fork_from, save_code, tensorboard, sync_tensorboard, monitor_gym, settings)
#    1519 wl = wandb_setup.singleton()
#    1521 wi = _WandbInit(wl, init_telemetry)
# -> 1523 wi.maybe_login(init_settings)
#    1524 run_settings, show_warnings = wi.make_run_settings(init_settings)
#    1526 if isinstance(run_settings.reinit, bool):
#
# File c:\python_projects\MIREA_NLP\.venv\Lib\site-packages\wandb\sdk\wandb_init.py:190, in _WandbInit.maybe_login(self, init_settings)
#     187 if run_settings._noop or run_settings._offline:
#     188     return
# --> 190 wandb_login._login(
#     191     anonymous=run_settings.anonymous,
#     192     host=run_settings.base_url,
#     193     force=run_settings.force,
#     194     _disable_warning=True,
#     195     _silent=run_settings.quiet or run_settings.silent,
#     196 )
#
# File c:\python_projects\MIREA_NLP\.venv\Lib\site-packages\wandb\sdk\wandb_login.py:320, in _login(anonymous, key, relogin, host, force, timeout, verify, referrer, update_api_key, _silent, _disable_warning)
#     318         key_is_pre_configured = True
#     319     else:
# --> 320         key, key_status = wlogin.prompt_api_key(referrer=referrer)
#     322 if verify:
#     323     _verify_login(key, wlogin._settings.base_url)
#
# File c:\python_projects\MIREA_NLP\.venv\Lib\site-packages\wandb\sdk\wandb_login.py:238, in _WandbLogin.prompt_api_key(self, referrer)
#     234 def prompt_api_key(
#     235     self, referrer: Optional[str] = None
#     236 ) -> Tuple[Optional[str], ApiKeyStatus]:
#     237     """Updates the global API key by prompting the user."""
# --> 238     key, status = self._prompt_api_key(referrer)
#     239     if status == ApiKeyStatus.NOTTY:
#     240         directive = (
#     241             "wandb login [your_api_key]"
#     242             if self._settings.x_cli_only_mode
#     243             else "wandb.login(key=[your_api_key])"
#     244         )
#
# File c:\python_projects\MIREA_NLP\.venv\Lib\site-packages\wandb\sdk\wandb_login.py:214, in _WandbLogin._prompt_api_key(self, referrer)
#     212 while True:
#     213     try:
# --> 214         key = apikey.prompt_api_key(
#     215             self._settings,
#     216             api=api,
#     217             no_offline=self._settings.force if self._settings else None,
#     218             no_create=self._settings.force if self._settings else None,
#     219             referrer=referrer,
#     220         )
#     221     except ValueError as e:
#     222         # invalid key provided, try again
#     223         wandb.termerror(e.args[0])
#
# File c:\python_projects\MIREA_NLP\.venv\Lib\site-packages\wandb\sdk\lib\apikey.py:192, in prompt_api_key(settings, api, input_callback, browser_callback, no_offline, no_create, local, referrer)
#     187             wandb.termlog(
#     188                 f"Logging into {host}. (Learn how to deploy a W&B server "
#     189                 f"locally: {url_registry.url('wandb-server')})"
#     190             )
#     191         wandb.termlog(_api_key_prompt_str(app_url, referrer))
# --> 192         key = input_callback(api_ask).strip()
#     193 elif result == LOGIN_CHOICE_NOTTY:
#     194     # TODO: Needs refactor as this needs to be handled by caller
#     195     return False
#
# File c:\python_projects\MIREA_NLP\.venv\Lib\site-packages\click\termui.py:168, in prompt(text, default, hide_input, confirmation_prompt, type, value_proc, prompt_suffix, show_default, err, show_choices)
#     166 while True:
#     167     while True:
# --> 168         value = prompt_func(prompt)
#     169         if value:
#     170             break
#
# File c:\python_projects\MIREA_NLP\.venv\Lib\site-packages\click\termui.py:151, in prompt.<locals>.prompt_func(text)
#     149 if hide_input:
#     150     echo(None, err=err)
# --> 151 raise Abort() from None
#
# Abort:

# %%
run.finish()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 run.finish()
#
# NameError: name 'run' is not defined

# %% [markdown]
# # Обучение собственной модели MLP

# %%
np.random.seed(1337)
random.seed(1337)

# %%
# initialize a model
model = MLP(2, [16, 16, 1]) # 2-layer neural network
print(model)
print("number of parameters", len(model.parameters()))
# Out:
# MLP of [Layer of [ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2)]
# Layer of [ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16)]
# Layer of [LinearNeuron(16)]]
# number of parameters 337

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# make up a dataset

from sklearn.datasets import make_moons
X, y = make_moons(n_samples=100, noise=0.1) # [n x 2], [n,]
y = y*2 - 1 # make y be -1 or 1
# visualize in 2D
plt.figure(figsize=(5,5))
plt.scatter(X[:,0], X[:,1], c=y, s=20, cmap='jet')

# %%
# loss function
def loss(batch_size=None):

    # inline DataLoader :)
    if batch_size is None:
        Xb, yb = X, y
    else:
        ri = np.random.permutation(X.shape[0])[:batch_size]
        Xb, yb = X[ri], y[ri]

    inputs = [list(map(Value, xrow)) for xrow in Xb]

    # forward the model to get scores
    scores = ...

    # svm "max-margin" loss
    # https://www.cs.cornell.edu/courses/cs4780/2018fa/lectures/lecturenote09.html
    # https://en.wikipedia.org/wiki/Hinge_loss
    losses = ...
    data_loss = sum(losses)/len(losses)
    # L2 regularization
    alpha = 1e-4
    reg_loss = ...

    total_loss = data_loss + reg_loss

    # also get accuracy
    accuracy = [(yi > 0) == (scorei.data > 0) for yi, scorei in zip(yb, scores)]
    return total_loss, sum(accuracy) / len(accuracy)

total_loss, acc = loss()
print(total_loss, acc)
# Out:
# Value(data=0.8742178866699549, grad=0) 0.54

# %%
#draw learning rate
learning_rate = lambda k: 1.0 - 0.9*k/100
x = list(range(100))
plt.plot(x, list(map(learning_rate, x)))

# %%
# optimization
for k in range(100):

    # forward
    total_loss, acc = loss()

    learning_rate = ...
    # backward (zero_grad + backward)
    ...
    # update (sgd)
    for p in model.parameters():
      ...

    if k % 1 == 0:
        print(f"step {k} loss {total_loss.data}, accuracy {acc*100}%")
# Out:
# step 34 loss 0.01917769152367769, accuracy 100.0%
# step 35 loss 0.019684119623731382, accuracy 100.0%
# step 36 loss 0.021326141038309505, accuracy 100.0%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-2c18473c982f> in <module>
#       3
#       4     # forward
# ----> 5     total_loss, acc = loss()
#       6
#       7     learning_rate = 1.0 - 0.9*k/100
#
# <ipython-input-37-951072a914d1> in loss(batch_size)
#      12
#      13     # forward the model to get scores
# ---> 14     scores = list(map(model, inputs))
#      15
#      16     # svm "max-margin" loss
#
# <ipython-input-33-b3e3dae4878b> in __call__(self, x)
#      50     def __call__(self, x):
#      51         for layer in self.layers:
# ---> 52             x = layer(x)
#      53         return x
#      54
#
# <ipython-input-33-b3e3dae4878b> in __call__(self, x)
#      33
#      34     def __call__(self, x):
# ---> 35         out = [n(x) for n in self.neurons]
#      36         return out[0] if len(out) == 1 else out
#      37
#
# <ipython-input-33-b3e3dae4878b> in <listcomp>(.0)
#      33
#      34     def __call__(self, x):
# ---> 35         out = [n(x) for n in self.neurons]
#      36         return out[0] if len(out) == 1 else out
#      37
#
# <ipython-input-33-b3e3dae4878b> in __call__(self, x)
#      18
#      19     def __call__(self, x):
# ---> 20         act = sum((xi*wi for xi, wi in zip(x, self.w)), self.b)
#      21         return act.relu() if self.nonlin else act
#      22
#
# <ipython-input-10-18468e5e09fc> in __add__(self, other)
#      10         self._op = _op # the op that produced this node, for graphviz / debugging / etc
#      11
# ---> 12     def __add__(self, other):
#      13         other = other if isinstance(other, Value) else Value(other)
#      14         out = Value(self.data + other.data, (self, other), '+')
#
# KeyboardInterrupt:

# %%
# visualize decision boundary

h = 0.25
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
Xmesh = np.c_[xx.ravel(), yy.ravel()]
inputs = [list(map(Value, xrow)) for xrow in Xmesh]
scores = list(map(model, inputs))
Z = np.array([s.data > 0 for s in scores])
Z = Z.reshape(xx.shape)

fig = plt.figure()
plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral, alpha=0.8)
plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.Spectral)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
# Out:
# (-1.60880919956848, 1.89119080043152)
