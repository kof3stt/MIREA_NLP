# %% [markdown]
# **Семинар 3**
# План занятия:
# - разбор класса Value (сторим собственный autograd)
# - обучение параметров полинома
# - построение MLP модели на основе класса Value
# - теоретический блок по визуализации обучения (wandb)
# - обучение собственной MLP модели

# %% [markdown]
# #Разбор класса Value

# %% [markdown]
# # Oбучение полинома

# %%
import numpy as np
import math
import random

xx = np.linspace(-math.pi, math.pi, 2000)
yy = np.sin(xx).tolist()

# %% [markdown]
# ### Класс Value

# %%
class Value:
    """ stores a single scalar value and its gradient """

    def __init__(self, data, _children=(), _op=''):
        self.data = data
        self.grad = 0
        # internal variables used for autograd graph construction
        self._backward = lambda: None # function
        self._prev = set(_children) # set of Value objects
        self._op = _op # the op that produced this node, string ('+', '-', ....)

    def __add__(self, other):
        other = other if isinstance(other, Value) else Value(other)
        out = Value(data=self.data + other.data, _children=(self, other), _op='+')

        def _backward():
            self.grad += out.grad
            other.grad += out.grad
        out._backward = _backward

        return out

    def __mul__(self, other):
        other = other if isinstance(other, Value) else Value(other)
        out = Value(data=self.data * other.data, _children=(self, other), _op='*')

        def _backward():
            self.grad += other.data * out.grad
            other.grad += self.data * out.grad
        out._backward = _backward

        return out

    def __pow__(self, other):
        assert isinstance(other, (int, float)), "only supporting int/float powers for now"
        out = Value(data=self.data ** other, _children=(self,), _op=f'**{other}')

        def _backward():
            self.grad += (other * self.data**(other - 1)) * out.grad
        out._backward = _backward

        return out

    def relu(self):
        out = Value(data=self.data if self.data > 0 else 0, _children=(self,), _op='ReLU')

        def _backward():
            self.grad += (out.data > 0) * out.grad
        out._backward = _backward

        return out

    def backward(self):
        # topological order all of the children in the graph
        topo = []
        visited = set()
        def build_topo(v):
            if v not in visited:
                visited.add(v)
                for child in v._prev:
                    build_topo(child)
                topo.append(v)
        build_topo(self)

        # go one variable at a time and apply the chain rule to get its gradient
        self.grad = 1
        for v in reversed(topo):
            v._backward()

    def __neg__(self): # -self
        return self * -1

    def __radd__(self, other): # other + self
        return self + other

    def __sub__(self, other): # self - other
        return self + (-other)

    def __rsub__(self, other): # other - self
        return other + (-self)

    def __rmul__(self, other): # other * self
        return self * other

    def __truediv__(self, other): # self / other
        return self * other**-1

    def __rtruediv__(self, other): # other / self
        return other * self**-1

    def __repr__(self):
        return f"Value(data={self.data}, grad={self.grad})"

# %%
a = Value(random.uniform(-1,1))
b = Value(random.uniform(-1,1))
c = Value(random.uniform(-1,1))
d = Value(random.uniform(-1,1))
parameters = [a, b, c, d]

# %%
pseudo_sin = lambda x: a + b * x + c * x ** 2 + d * x ** 3

# %%
import sys
print(sys.getrecursionlimit())
# Out:
# 3000

# %%
sys.setrecursionlimit(5000)

# %%
#%%wandb

for epoch in range(1):
  for _ in range(2000):
    step = random.choice(range(2000))
    polynom = pseudo_sin(xx[step])
    #print(polynom)
    loss = (yy[step] - polynom) ** 2

    #wandb.log({'loss': loss.data})

    #set grad to zero
    for param in parameters:
      param.grad = 0

    #call backward
    loss.backward()

    #update weights
    for param in parameters:
        param.data -= 0.001 * param.grad

    if step % 10 == 0:
          print(f"{step} step - loss {loss}")




print(f'Result: y = {a.data} + {b.data} x + {c.data} x^2 + {d.data} x^3')
# Out:
# 1790 step - loss Value(data=56.72394701012261, grad=1)
# 920 step - loss Value(data=0.0659448269353249, grad=1)
# 920 step - loss Value(data=0.058151889572341194, grad=1)
# 50 step - loss Value(data=2.1057628589488884, grad=1)
# 80 step - loss Value(data=1.5919145799483918, grad=1)
# 1090 step - loss Value(data=0.6846696527147463, grad=1)
# 900 step - loss Value(data=0.0943814186785651, grad=1)
# 1450 step - loss Value(data=4.094070423195292, grad=1)
# 1470 step - loss Value(data=3.825824737414737, grad=1)
# 540 step - loss Value(data=2.370564539373311, grad=1)
# 1470 step - loss Value(data=3.0223340569643455, grad=1)
# 880 step - loss Value(data=0.19695796864793286, grad=1)
# 130 step - loss Value(data=5.850833304486519, grad=1)
# 850 step - loss Value(data=0.2980877980230605, grad=1)
# 620 step - loss Value(data=2.4418843893685502, grad=1)
# 540 step - loss Value(data=2.4679445704908196, grad=1)
# 70 step - loss Value(data=0.08023975313878659, grad=1)
# 1980 step - loss Value(data=4.861701941406383, grad=1)
# 510 step - loss Value(data=4.328566669762619, grad=1)
# 40 step - loss Value(data=0.3266712781502894, grad=1)
# 1060 step - loss Value(data=0.3187989235842538, grad=1)
# 1370 step - loss Value(data=2.6567272188814557, grad=1)
# 1160 step - loss Value(data=0.926074792968673, grad=1)
# 470 step - loss Value(data=2.704742476382043, grad=1)
# 900 step - loss Value(data=0.06624217019973848, grad=1)
# 550 step - loss Value(data=1.888020400734716, grad=1)
# 950 step - loss Value(data=3.866603516627435e-06, grad=1)
# 1920 step - loss Value(data=0.030555894788278904, grad=1)
# 1100 step - loss Value(data=0.4606634096842347, grad=1)
# 1080 step - loss Value(data=0.34766585755968155, grad=1)
# 1900 step - loss Value(data=1.1380655704808638, grad=1)
# 170 step - loss Value(data=0.10341172052362617, grad=1)
# 720 step - loss Value(data=0.7516463588410744, grad=1)
# 1050 step - loss Value(data=0.18099797313828245, grad=1)
# 160 step - loss Value(data=0.04939039939030558, grad=1)
# 1030 step - loss Value(data=0.11190810532411594, grad=1)
# 670 step - loss Value(data=1.1500262725375445, grad=1)
# 960 step - loss Value(data=0.00017391046387210608, grad=1)
# 540 step - loss Value(data=1.4547525886761508, grad=1)
# 640 step - loss Value(data=1.1031780235150614, grad=1)
# 1940 step - loss Value(data=0.9452566249779951, grad=1)
# 1580 step - loss Value(data=1.3106424304880784, grad=1)
# 860 step - loss Value(data=0.14011854909701565, grad=1)
# 430 step - loss Value(data=2.428744235860902, grad=1)
# 1140 step - loss Value(data=0.5323770737213962, grad=1)
# 670 step - loss Value(data=0.8052160393412217, grad=1)
# 1860 step - loss Value(data=1.399249893670491, grad=1)
# 1550 step - loss Value(data=1.5793178729804902, grad=1)
# 690 step - loss Value(data=0.6723542642521317, grad=1)
# 40 step - loss Value(data=0.8604052714975187, grad=1)
# 1800 step - loss Value(data=2.561751955642239, grad=1)
# 1890 step - loss Value(data=0.25791779954377225, grad=1)
# 850 step - loss Value(data=0.14011030277290826, grad=1)
# 1360 step - loss Value(data=1.298978535395888, grad=1)
# 210 step - loss Value(data=0.0004598369654448291, grad=1)
# 1170 step - loss Value(data=0.511689617020956, grad=1)
# 1060 step - loss Value(data=0.1327624356846109, grad=1)
# 1110 step - loss Value(data=0.27769876489475986, grad=1)
# 1660 step - loss Value(data=0.6823616773433708, grad=1)
# 320 step - loss Value(data=0.8711917822889276, grad=1)
# 520 step - loss Value(data=0.9497685788866539, grad=1)
# 190 step - loss Value(data=0.03608239682906044, grad=1)
# 80 step - loss Value(data=0.09635593491355475, grad=1)
# 1960 step - loss Value(data=0.5148721098567945, grad=1)
# 1910 step - loss Value(data=1.4340803592779303, grad=1)
# 1970 step - loss Value(data=3.2004860811418134, grad=1)
# 1550 step - loss Value(data=0.9887779291671139, grad=1)
# 90 step - loss Value(data=2.6303797860029534, grad=1)
# 130 step - loss Value(data=0.003278288789262941, grad=1)
# 650 step - loss Value(data=0.7109260978070499, grad=1)
# 320 step - loss Value(data=0.26927543628727607, grad=1)
# 1250 step - loss Value(data=0.6032845582900961, grad=1)
# 830 step - loss Value(data=0.16761089775000218, grad=1)
# 640 step - loss Value(data=0.6426367908291261, grad=1)
# 1340 step - loss Value(data=0.7015276354754995, grad=1)
# 1670 step - loss Value(data=0.3932214314791566, grad=1)
# 1100 step - loss Value(data=0.18007797420166294, grad=1)
# 990 step - loss Value(data=0.011343949301212602, grad=1)
# 110 step - loss Value(data=0.33338513350688564, grad=1)
# 720 step - loss Value(data=0.31054575513846694, grad=1)
# 1180 step - loss Value(data=0.42922985527492774, grad=1)
# 1730 step - loss Value(data=0.7648926298650193, grad=1)
# 1520 step - loss Value(data=1.0864757794988942, grad=1)
# 760 step - loss Value(data=0.22087927408826305, grad=1)
# 1280 step - loss Value(data=0.6394284484448794, grad=1)
# 1030 step - loss Value(data=0.04706373331122244, grad=1)
# 850 step - loss Value(data=0.07524548359376618, grad=1)
# 1960 step - loss Value(data=1.5045445105504056, grad=1)
# 420 step - loss Value(data=0.30198174733441724, grad=1)
# 660 step - loss Value(data=0.39571870452730495, grad=1)
# 920 step - loss Value(data=0.007792263229187218, grad=1)
# 130 step - loss Value(data=0.10644285166673387, grad=1)
# 1560 step - loss Value(data=0.8505561017931706, grad=1)
# 1730 step - loss Value(data=0.4999584643379334, grad=1)
# 1490 step - loss Value(data=0.650337999426378, grad=1)
# 1860 step - loss Value(data=0.031143994758105233, grad=1)
# 510 step - loss Value(data=0.4851665371716568, grad=1)
# 1070 step - loss Value(data=0.08626863818797299, grad=1)
# 410 step - loss Value(data=0.35087851896593214, grad=1)
# 1420 step - loss Value(data=0.6321338967475596, grad=1)
# 560 step - loss Value(data=0.3425851800615546, grad=1)
# 1550 step - loss Value(data=0.35577182480299685, grad=1)
# 160 step - loss Value(data=0.22790808062904114, grad=1)
# 290 step - loss Value(data=0.0764150848387404, grad=1)
# 840 step - loss Value(data=0.06222815798195081, grad=1)
# 230 step - loss Value(data=0.11144625792529883, grad=1)
# 720 step - loss Value(data=0.23143359926095156, grad=1)
# 1920 step - loss Value(data=0.05135592069963226, grad=1)
# 260 step - loss Value(data=0.13972325471696395, grad=1)
# 200 step - loss Value(data=0.30520739841293126, grad=1)
# 1830 step - loss Value(data=0.01517735964789582, grad=1)
# 1550 step - loss Value(data=0.43579150647778875, grad=1)
# 1530 step - loss Value(data=0.4314935268923619, grad=1)
# 500 step - loss Value(data=0.3065596147880404, grad=1)
# 1160 step - loss Value(data=0.19404487265669657, grad=1)
# 1110 step - loss Value(data=0.11942011594926483, grad=1)
# 1650 step - loss Value(data=0.11392389796510763, grad=1)
# 30 step - loss Value(data=0.4341252004421843, grad=1)
# 1350 step - loss Value(data=0.44251817554797646, grad=1)
# 1800 step - loss Value(data=7.829400534764022e-05, grad=1)
# 420 step - loss Value(data=0.22886294075572317, grad=1)
# 1990 step - loss Value(data=0.21787676384058102, grad=1)
# 60 step - loss Value(data=0.06420387092661269, grad=1)
# 1410 step - loss Value(data=0.4300487892269394, grad=1)
# 1760 step - loss Value(data=0.5034596372268589, grad=1)
# 1280 step - loss Value(data=0.2783484663625118, grad=1)
# 1150 step - loss Value(data=0.13809913271634325, grad=1)
# 1700 step - loss Value(data=0.10623230762695728, grad=1)
# 450 step - loss Value(data=0.22537156224083515, grad=1)
# 1150 step - loss Value(data=0.13420221043995512, grad=1)
# 1810 step - loss Value(data=0.01122130175847229, grad=1)
# 1720 step - loss Value(data=0.019427393244993867, grad=1)
# 150 step - loss Value(data=0.0522408524825581, grad=1)
# 1310 step - loss Value(data=0.29104852774611745, grad=1)
# 630 step - loss Value(data=0.1860821653319714, grad=1)
# 480 step - loss Value(data=0.159614940570816, grad=1)
# 1840 step - loss Value(data=0.1829468747274954, grad=1)
# 1200 step - loss Value(data=0.18302837945775996, grad=1)
# 150 step - loss Value(data=0.06422765908469347, grad=1)
# 1090 step - loss Value(data=0.06366466169156663, grad=1)
# 960 step - loss Value(data=0.000326612057351932, grad=1)
# 1700 step - loss Value(data=0.016314278372293805, grad=1)
# 1990 step - loss Value(data=0.7717105534919882, grad=1)
# 240 step - loss Value(data=0.013929062129124748, grad=1)
# 1730 step - loss Value(data=0.0559512886522711, grad=1)
# 1180 step - loss Value(data=0.14513707711555363, grad=1)
# 1770 step - loss Value(data=0.004648282337093108, grad=1)
# 480 step - loss Value(data=0.1875564672208186, grad=1)
# 140 step - loss Value(data=0.0017652397430644043, grad=1)
# 1400 step - loss Value(data=0.2590294958058166, grad=1)
# 530 step - loss Value(data=0.16977249463665592, grad=1)
# 30 step - loss Value(data=0.04673371508886249, grad=1)
# 1200 step - loss Value(data=0.15437851225435076, grad=1)
# 1180 step - loss Value(data=0.134592077070427, grad=1)
# 850 step - loss Value(data=0.024792989124003222, grad=1)
# 670 step - loss Value(data=0.12389819731264412, grad=1)
# 810 step - loss Value(data=0.04330207933420528, grad=1)
# 1210 step - loss Value(data=0.14556719988373082, grad=1)
# 750 step - loss Value(data=0.07672893903794727, grad=1)
# 1990 step - loss Value(data=0.27282575698074285, grad=1)
# 990 step - loss Value(data=0.003961940667356112, grad=1)
# 680 step - loss Value(data=0.10397836975017577, grad=1)
# 1230 step - loss Value(data=0.15727055949255841, grad=1)
# 640 step - loss Value(data=0.10722348140998686, grad=1)
# 1000 step - loss Value(data=0.005428389609893129, grad=1)
# 1850 step - loss Value(data=0.00731679869643573, grad=1)
# 1030 step - loss Value(data=0.01273366797857699, grad=1)
# 1700 step - loss Value(data=0.003257158508074299, grad=1)
# 480 step - loss Value(data=0.11068073458094822, grad=1)
# 1340 step - loss Value(data=0.18496351540226305, grad=1)
# 100 step - loss Value(data=0.17625408285032787, grad=1)
# 550 step - loss Value(data=0.09818300557431249, grad=1)
# 110 step - loss Value(data=5.8287670807431865e-05, grad=1)
# 470 step - loss Value(data=0.054272530250604425, grad=1)
# 460 step - loss Value(data=0.039653100309406296, grad=1)
# 1420 step - loss Value(data=0.1378247483871681, grad=1)
# 600 step - loss Value(data=0.08321440738556378, grad=1)
# 380 step - loss Value(data=0.04844333482900828, grad=1)
# 80 step - loss Value(data=0.046371436795829245, grad=1)
# 1630 step - loss Value(data=0.03758538378814835, grad=1)
# 1080 step - loss Value(data=0.029390721066154927, grad=1)
# 520 step - loss Value(data=0.06909999180594097, grad=1)
# 410 step - loss Value(data=0.02760952158776033, grad=1)
# 830 step - loss Value(data=0.021766335373974443, grad=1)
# 1320 step - loss Value(data=0.13019021986301071, grad=1)
# 1330 step - loss Value(data=0.14816168101349866, grad=1)
# 1770 step - loss Value(data=0.0064606499912794185, grad=1)
# 1170 step - loss Value(data=0.07223750771847058, grad=1)
# 1050 step - loss Value(data=0.017301295820424775, grad=1)
# 250 step - loss Value(data=2.1694676534183702e-07, grad=1)
# 610 step - loss Value(data=0.06515233411370468, grad=1)
# 930 step - loss Value(data=0.0004515713422617934, grad=1)
# 60 step - loss Value(data=0.0019340543887902979, grad=1)
# 1180 step - loss Value(data=0.07686585291837986, grad=1)
# 180 step - loss Value(data=0.0002062945633425287, grad=1)
# 1200 step - loss Value(data=0.08695592989948793, grad=1)
# 1780 step - loss Value(data=0.07560238764137964, grad=1)
# 390 step - loss Value(data=0.024777036143642697, grad=1)
# 250 step - loss Value(data=0.0037567704472497234, grad=1)
# 760 step - loss Value(data=0.03965260442093304, grad=1)
# 700 step - loss Value(data=0.05587137868143672, grad=1)
# 970 step - loss Value(data=0.0007135389490662929, grad=1)
# 1710 step - loss Value(data=0.008804646172823626, grad=1)
# 310 step - loss Value(data=0.059614302464186655, grad=1)
# 130 step - loss Value(data=0.008991642673169906, grad=1)
# 170 step - loss Value(data=0.0029281263456166005, grad=1)
# 470 step - loss Value(data=0.04034715228178382, grad=1)
# 1550 step - loss Value(data=0.053652836162011955, grad=1)
# 630 step - loss Value(data=0.05007959210302383, grad=1)
# 1950 step - loss Value(data=0.2153952039569567, grad=1)
# 320 step - loss Value(data=0.005231531922312555, grad=1)
# 1230 step - loss Value(data=0.08025676214335849, grad=1)
# Result: y = -0.05785774935324586 + 0.632950554830854 x + 0.006601725877155853 x^2 + -0.06874016823923074 x^3

# %%
import matplotlib.pyplot as plt
plt.plot(xx, [y.data for y in list(map(pseudo_sin, xx))])

# %% [markdown]
# #Построение MLP модели на основе класса Value

# %%
import random

class Module:

    def zero_grad(self):
        for p in parameters:
            p.grad = 0

    def parameters(self):
        return []

class Neuron(Module):

    def __init__(self, nin, nonlin=True):
        self.w = [Value(random.uniform(-1,1)) for _ in range(nin)]
        self.b = Value(random.uniform(-1,1))
        self.nonlin = nonlin

    def __call__(self, x):
        act = sum([x[i] * self.w[i] for i in range(len(self.w))]) + self.b
        return act.relu() if self.nonlin else act

    def parameters(self):
        return self.w + [self.b]

    def __repr__(self):
        return f"{'ReLU' if self.nonlin else 'Linear'}Neuron({len(self.w)})"

class Layer(Module):

    def __init__(self, nin, nout, **kwargs):
        self.neurons = [Neuron(nin) for _ in range(nout)]

    def __call__(self, x):
        out = [neuron(x) for neuron in self.neurons]
        return out[0] if len(out) == 1 else out

    def parameters(self):
        out = []
        for neuron in self.neurons:
            out.extend(neuron.parameters())
        return out

    def __repr__(self):
        return f"Layer of [{', '.join(str(n) for n in self.neurons)}]"

class MLP(Module):

    def __init__(self, nin, nouts):
        sz = [nin] + nouts
        self.layers = [Layer(sz[i], sz[i+1], nonlin=(i!=len(nouts)-1)) for i in range(len(nouts))]

    def __call__(self, x):
        for layer in self.layers:
            x = layer(x)
        return x

    def parameters(self):
        params = []
        for layer in self.layers:
            params.extend(layer.parameters())
        return params

    def __repr__(self):
        repr = '\n'.join(str(layer) for layer in self.layers)
        return f"MLP of [{repr}]"

# %% [markdown]
# # Визуализация обучения

# %% [markdown]
# https://docs.wandb.ai/guides/integrations/pytorch

# %% [markdown]
# https://docs.wandb.ai/ref/python/watch

# %% [markdown]
# https://docs.wandb.ai/guides/track/jupyter

# %%
# !pip install wandb

# %%
# !wandb login

# %%
import wandb
run = wandb.init(project="polynom_learning_")

# %%
run.finish()

# %% [markdown]
# # Обучение собственной модели MLP

# %%
np.random.seed(1337)
random.seed(1337)

# %%
# initialize a model
model = MLP(2, [16, 16, 1]) # 2-layer neural network
print(model)
print("number of parameters", len(model.parameters()))

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# make up a dataset

from sklearn.datasets import make_moons
X, y = make_moons(n_samples=100, noise=0.1) # [n x 2], [n,]
y = y*2 - 1 # make y be -1 or 1
# visualize in 2D
plt.figure(figsize=(5,5))
plt.scatter(X[:,0], X[:,1], c=y, s=20, cmap='jet')

# %%
# loss function
def loss(batch_size=None):

    # inline DataLoader :)
    if batch_size is None:
        Xb, yb = X, y
    else:
        ri = np.random.permutation(X.shape[0])[:batch_size]
        Xb, yb = X[ri], y[ri]

    inputs = [list(map(Value, xrow)) for xrow in Xb]

    # forward the model to get scores
    scores = ...

    # svm "max-margin" loss
    # https://www.cs.cornell.edu/courses/cs4780/2018fa/lectures/lecturenote09.html
    # https://en.wikipedia.org/wiki/Hinge_loss
    losses = ...
    data_loss = sum(losses)/len(losses)
    # L2 regularization
    alpha = 1e-4
    reg_loss = ...

    total_loss = data_loss + reg_loss

    # also get accuracy
    accuracy = [(yi > 0) == (scorei.data > 0) for yi, scorei in zip(yb, scores)]
    return total_loss, sum(accuracy) / len(accuracy)

total_loss, acc = loss()
print(total_loss, acc)

# %%
#draw learning rate
learning_rate = lambda k: 1.0 - 0.9*k/100
x = list(range(100))
plt.plot(x, list(map(learning_rate, x)))

# %%
# optimization
for k in range(100):

    # forward
    total_loss, acc = loss()

    learning_rate = ...
    # backward (zero_grad + backward)
    ...
    # update (sgd)
    for p in model.parameters():
      ...

    if k % 1 == 0:
        print(f"step {k} loss {total_loss.data}, accuracy {acc*100}%")

# %%
# visualize decision boundary

h = 0.25
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
Xmesh = np.c_[xx.ravel(), yy.ravel()]
inputs = [list(map(Value, xrow)) for xrow in Xmesh]
scores = list(map(model, inputs))
Z = np.array([s.data > 0 for s in scores])
Z = Z.reshape(xx.shape)

fig = plt.figure()
plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral, alpha=0.8)
plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.Spectral)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
